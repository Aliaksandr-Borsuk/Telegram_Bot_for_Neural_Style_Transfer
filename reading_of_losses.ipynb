# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pickle
#  в path передаём адрес файла losses
path = 'badger_style_transfering_bot\12345678\losses_1673860216.pkl'
with open(path, 'rb') as file:
    losses = pickle.load(file)

#
plt.plot(losses['style'], label='style')
plt.plot(losses['content'], label = 'comtent')
plt.legend(loc = 'best')
# convert y-axis to Logarithmic scale
plt.yscale("log")
